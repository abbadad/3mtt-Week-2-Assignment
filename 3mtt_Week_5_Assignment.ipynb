# %% [markdown]
# <a href="https://colab.research.google.com/github/abbadad/3mtt-Week-2-Assignment/blob/main/3mtt_Week_5_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment**:
# Use Pandas to clean and preprocess a messy dataset, documenting the steps taken during the cleaning process.

# %%
# Steps of Preprocessing of Data
# 1. Import Necessary Liberary
# 2. Read Data Set
# 3. Sanity Check of Data
# 4. Exploratory Data Analysis
# 5. Missing Value Treatment
# 6. Outliers Treatment
# 7. Duplicate and Gabage Value Treatment

# %% [markdown]
# **Import Necessary Libery**

# %%
import pandas as pd

# %% [markdown]
# **Read Dataset**

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path= '/content/drive/MyDrive/Lab Inventory.csv'
df= pd.read_csv(path)
df.head()
# Out:
#        ID    Name Description Unit price  Quantity \nin stock Inventory value  \
# 0  IN0001  Item 1      Desc 1     $51.00                   25         #VALUE!
# 1  IN0002  Item 2      Desc 2     $93.00                  132         #VALUE!
# 2  IN0003  Item 3      Desc 3     $57.00                  151             NaN
# 3  IN0004  Item 4      Desc 4     $19.00                  186             NaN
# 4  IN0005  Item 5      Desc 5     $75.00                   62          $1,275
#
#    Reorder level  Reorder time in days  Quantity \nin reorder Discontinued?
# 0             29                    13                     50           NaN
# 1            231                     4                     50           NaN
# 2            114                    11                    150           NaN
# 3            158                     6                     50           NaN
# 4             39                    12                     50           NaN

# %%
df.tail()
# Out:
#         ID     Name Description Unit price  Quantity \nin stock  \
# 20  IN0021  Item 21     Desc 21     $19.00                  112
# 21  IN0022  Item 22     Desc 22     $24.00                  182
# 22  IN0023  Item 23     Desc 23     $29.00                  106
# 23  IN0024  Item 24     Desc 24     $75.00                  173
# 24  IN0025  Item 25     Desc 25     $14.00                   28
#
#    Inventory value  Reorder level  Reorder time in days  \
# 20          $5,529             75                    11
# 21             $72            132                    15
# 22         $11,726            142                     1
# 23          $1,984            127                     9
# 24          $2,128             21                     8
#
#     Quantity \nin reorder Discontinued?
# 20                     50           NaN
# 21                    150           NaN
# 22                    150           Yes
# 23                    100           NaN
# ...

# %% [markdown]
# **Sanity Check of Data**

# %%
# Shape
df.shape
# Out:
# (25, 10)

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    ID                   25 non-null     object
#  1   Name                  25 non-null     object
#  2   Description           25 non-null     object
#  3   Unit price            25 non-null     object
#  4   Quantity
# in stock    25 non-null     int64
#  5   Inventory value       23 non-null     object
#  6   Reorder level         25 non-null     int64
#  7   Reorder time in days  25 non-null     int64
#  8   Quantity
# in reorder  25 non-null     int64
#  9   Discontinued?         3 non-null      object
# dtypes: int64(4), object(6)
# memory usage: 2.1+ KB

# %%
# Finding Missing Value
df.isnull().sum()
# Out:
#  ID                       0
# Name                      0
# Description               0
# Unit price                0
# Quantity \nin stock       0
# Inventory value           2
# Reorder level             0
# Reorder time in days      0
# Quantity \nin reorder     0
# Discontinued?            22
# dtype: int64

# %%
# Finding Duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# Identifying Garbage value
for i in df.select_dtypes(include="object").columns:
  print(df[i].value_counts())
  print("***"*10)
# Out:
# IN0001    1
# IN0014    1
# IN0024    1
# IN0023    1
# IN0022    1
# IN0021    1
# IN0020    1
# IN0019    1
# IN0018    1
# IN0017    1
# IN0016    1
# IN0015    1
# IN0013    1
# IN0002    1
# IN0012    1
# IN0011    1
# IN0010    1
# IN0009    1
# IN0008    1
# IN0007    1
# IN0006    1
# IN0005    1
# IN0004    1
# IN0003    1
# IN0025    1
# Name:  ID, dtype: int64
# ******************************
# Item 1     1
# Item 14    1
# Item 24    1
# Item 23    1
# Item 22    1
# Item 21    1
# Item 20    1
# Item 19    1
# Item 18    1
# Item 17    1
# Item 16    1
# Item 15    1
# Item 13    1
# Item 2     1
# Item 12    1
# Item 11    1
# Item 10    1
# Item 9     1
# Item 8     1
# Item 7     1
# Item 6     1
# Item 5     1
# Item 4     1
# Item 3     1
# Item 25    1
# Name: Name, dtype: int64
# ******************************
# Desc 1     1
# Desc 14    1
# Desc 24    1
# Desc 23    1
# Desc 22    1
# Desc 21    1
# Desc 20    1
# Desc 19    1
# Desc 18    1
# Desc 17    1
# ...
